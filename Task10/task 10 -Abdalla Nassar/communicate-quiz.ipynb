# %% [markdown]
# # Communicating Results Quiz
# Now let's answer the same questions found in "Drawing Conclusions Quiz" using visualizations.\
# Using the grocery store dataset `store_data.csv` , create plots with appropriate labeling, colors and size to communicate the results of the following questions.
#
# Which store has the highest total sales for the last month?\
# Which store makes the most sales on average?\
# Which store sells the most during the week of March 13th, 2016?\
# Which store has the most sales in the latest 3-month period?\
# **Which store is the most consistent ? (important)**

# %% [markdown]
# <p style="font-family: Arial; font-size:2em;color:gold; text-align:center;">---->Edited By Abdalla Nassar<---- </p>

# %%
# import and load the data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
store=pd.read_csv("store_data.csv")
store.head(10)
# Out:
#          week  storeA  storeB  storeC  storeD  storeE
# 0  2014-05-04    2643    8257    3893    6231    1294
# 1  2014-05-11    6444    5736    5634    7092    2907
# 2  2014-05-18    9646    2552    4253    5447    4736
# 3  2014-05-25    5960   10740    8264    6063     949
# 4  2014-06-01    7412    7374    3208    3985    3023
# 5  2014-06-08    1289   10137    5070    7163    1703
# 6  2014-06-15    6282    3925    5528    4748    3351
# 7  2014-06-22    5135    7317    5530    4595     104
# 8  2014-06-29   11766   12560    3199    4676    3573
# 9  2014-07-06    8567    3228     927    3277     168

# %%
# explore the data (use plots only)
store.hist(figsize=(11,11));

# %%
# plot sales for the last month
store["week"] = pd.to_datetime(store["week"])
store.iloc[196:].sum().plot(kind='pie')
#انا اخد اخر اربع قيم 
#2/4/2018	4853	6503	4187	5956	1458
#2/11/2018	9202	3677	4540	6186	243
#2/18/2018	3512	7511	4151	5596	3501
#2/25/2018	7560	6904	3569	5045	2585
# Out:
# C:\Users\Abdalla\AppData\Local\Temp\ipykernel_5488\2487364261.py:3: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   store.iloc[196:].sum().plot(kind='pie')
# <Axes: >

# %%
# plot average sales
store.mean()[0:].plot.bar()
# Out:
# C:\Users\Abdalla\AppData\Local\Temp\ipykernel_5488\906631235.py:2: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   store.mean()[0:].plot.bar()
# <Axes: >

# %%
# plot sales for the week of March 13th, 2016
store[store["week"] == "2016-03-13"].sum().plot.pie()
# Out:
# C:\Users\Abdalla\AppData\Local\Temp\ipykernel_5488\1709252745.py:2: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   store[store["week"] == "2016-03-13"].sum().plot.pie()
# <Axes: >

# %%
# plot sales for the lastest 3-month periods

store.iloc[187:].sum().plot(kind='pie')




#database
# week         storeA	storeB	storeC	storeD	storeE	
# 2017-12-03	5179	3850	6121	6778	113
# 2017-12-10	9348	5624	5446	5448	227
# 2017-12-17	5310	8647	5680	7049	3578
# 2017-12-24	8976	9503	6240	3882	2890
# 2017-12-31	11875	1527	6711	5265	1701
# 2018-01-07	8978	11312	4158	5019	3842
# 2018-01-14	6963	4014	4215	7153	3097
# 2018-01-21	5553	3971	3761	6255	3071
# 2018-01-28 	282	    6351    7759    5558	 1028
# 2018-02-04	4853	6503	4187	5956	1458
# 2018-02-11	9202	3677	4540	6186	243
# 2018-02-18	3512	7511	4151	5596	3501
# 2018-02-25	7560	6904	3569	5045	2585
# Out:
# C:\Users\Abdalla\AppData\Local\Temp\ipykernel_5488\4103307345.py:3: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   store.iloc[187:].sum().plot(kind='pie')
# <Axes: >

# %% [markdown]
# ______________________________________________________________________________________________________________________________

# %%
# Which store has the highest total sales for the last month?
print(store.sum()[1:].to_string())
print("storeB has highest total sale")
#storeB has the highest total sales
# Out:
# storeB    1351342
# storeC     988421
# storeD    1086281
# storeE     516005
# storeB has highest total sale
# C:\Users\Abdalla\AppData\Local\Temp\ipykernel_5488\1000690126.py:2: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(store.sum()[1:].to_string())

# %%
# Which store makes the most sales on average?
print(store.mean()[0:].to_string())
print("-"*50)
print("storeA :{} ".format(store["storeA"].mean()))
print("storeB :{} ".format(store["storeB"].mean()))
print("storeC :{} ".format(store["storeC"].mean()))
print("storeD :{} ".format(store["storeD"].mean()))
print("storeE :{} ".format(store["storeE"].mean()))
print("storeB has most sales on average")

#storeB has most sales on average
# Out:
# storeA    5865.480
# storeB    6756.710
# storeC    4942.105
# storeD    5431.405
# storeE    2580.025
# --------------------------------------------------
# storeA :5865.48
# storeB :6756.71
# storeC :4942.105
# storeD :5431.405
# storeE :2580.025
# storeB has most sales on average
# C:\Users\Abdalla\AppData\Local\Temp\ipykernel_5488\3974385691.py:2: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   print(store.mean()[0:].to_string())

# %%
# Which store sells the most during the week of March 13th, 2016? ---------

# Set the 'week' column as the index
store.set_index("week", inplace=True)
sales_data = store.loc['3/13/2016']
max_sales_store = sales_data.idxmax()

max_sales_store
# Out:
# 'storeD'

# %%
# Which store has the most sales in the latest 3-month period? -----------
latest_3_month_period = store.iloc[187:].sum().idxmax()
latest_3_month_period

#database
# week         storeA	storeB	storeC	storeD	storeE				
# 2017-12-03	5179	3850	6121	6778	113
# 2017-12-10	9348	5624	5446	5448	227
# 2017-12-17	5310	8647	5680	7049	3578
# 2017-12-24	8976	9503	6240	3882	2890
# 2017-12-31	11875	1527	6711	5265	1701
# 2018-01-07	8978	11312	4158	5019	3842
# 2018-01-14	6963	4014	4215	7153	3097
# 2018-01-21	5553	3971	3761	6255	3071
# 2018-01-28 	282	    6351    7759    5558	 1028
# 2018-02-04	4853	6503	4187	5956	1458
# 2018-02-11	9202	3677	4540	6186	243
# 2018-02-18	3512	7511	4151	5596	3501
# 2018-02-25	7560	6904	3569	5045	2585
# Out:
# 'storeA'

# %%
# What is the most consistent store in sales ? ------------- 
std_dev_by_store = store.std().idxmin()

std_dev_by_store
# Out:
# 'storeD'
